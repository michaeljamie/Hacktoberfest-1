# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS'

# %%
os.chdir('C:\\Users\\ASUS\\Downloads')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Downloads'

# %%
movies = pd.read_csv('P4-Movie-Ratings.csv')

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns = ['Flim','Genre', 'CriticsRating', 'AudienceRating','BudgetMillions', 'Year']

# %%
movies.columns
# Out:
# Index(['Flim', 'Genre', 'CriticsRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies.head()
# Out:
#                     Flim      Genre  CriticsRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy             87              81
# 1            10,000 B.C.  Adventure              9              44
# 2             12 Rounds      Action             30              52
# 3              127 Hours  Adventure             93              84
# 4              17 Again      Comedy             55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Flim              559 non-null object
# Genre             559 non-null object
# CriticsRating     559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticsRating  AudienceRating  BudgetMillions         Year
# count     559.000000      559.000000      559.000000   559.000000
# mean       47.309481       58.744186       50.236136  2009.152057
# std        26.413091       16.826887       48.731817     1.362632
# min         0.000000        0.000000        0.000000  2007.000000
# 25%        25.000000       47.000000       20.000000  2008.000000
# 50%        46.000000       58.000000       35.000000  2009.000000
# 75%        70.000000       72.000000       65.000000  2010.000000
# max        97.000000       96.000000      300.000000  2011.000000

# %%
movies.Flim = movies.Flim.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Flim              559 non-null category
# Genre             559 non-null object
# CriticsRating     559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies.Year = movies.Year.astype('category')
movies.Genre = movies.Genre.astype('category')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
 a = sns.lineplot(data=movies,x= 'CriticsRating', y= 'AudienceRating')

# %%
j = sns.jointplot(data=movies, x= 'CriticsRating', y= 'AudienceRating')

# %%
j = sns.jointplot(data=movies, x= 'CriticsRating', y= 'AudienceRating', kind = 'hex')

# %%
j = sns.jointplot(data=movies, x= 'CriticsRating', y= 'AudienceRating', kind = 'kde')

# %%
j = sns.jointplot(data=movies, x= 'CriticsRating', y= 'AudienceRating', kind = 'reg')

# %%
j = sns.jointplot(data=movies, x= 'CriticsRating', y= 'AudienceRating', kind = 'resid')

# %%
m1 = sns.distplot(movies.AudienceRating, bins = 15)

# %%
sns.set_style('darkgrid')
n1 = plt.hist(movies.AudienceRating, bins = 15)

# %%
m1 = sns.distplot(movies.AudienceRating, bins = 15)

# %%
sns.set_style('darkgrid')
visl = sns.lmplot(data=movies, x='CriticsRating', y='AudienceRating',\
                 fit_reg=False, hue='Genre',\
                 size=6, aspect=1)

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions, \
         movies[movies.Genre=='Drama'].BudgetMillions],\
         bins = 15, stacked = True)
plt.show()

# %%
list1 = []
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillions)
    
h = plt.hist(list1, bins = 30, stacked = True)

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
k1 = sns.kdeplot(movies.CriticsRating, movies.AudienceRating,\
                 shade = True, shade_lowest = False, cmap = 'Reds')

# %%
k1 = sns.kdeplot(movies.CriticsRating, movies.AudienceRating,\
                 shade = True, shade_lowest = False, cmap = 'Reds')
k1b = sns.kdeplot(movies.CriticsRating, movies.AudienceRating,\
                  cmap = 'Reds')

# %%
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticsRating)

# %%
sns.set_style('dark')
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)

# %%
f, ax = plt.subplots(1,2, figsize=(12,6),sharex= True, sharey=True)
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticsRating, ax = ax[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax = ax[1])
k1.set(xlim=(-20,160))
# Out:
# [(-20.0, 160.0)]

# %%
z = sns.violinplot(data=movies, x= 'Genre', y= 'CriticsRating')

# %%
x = sns.boxplot(data=movies, x= 'Genre', y= 'CriticsRating')

# %%
g= sns.FacetGrid(movies, row= 'Genre',col='Year', hue = 'Genre')
kws = dict(s=80, linewidth=0.5, edgecolor='black')
g= g.map(plt.scatter, 'CriticsRating', 'AudienceRating', **kws)

# %%
g= sns.FacetGrid(movies, row= 'Genre',col='Year', hue = 'Genre')
kws = dict(s=80, linewidth=0.5, edgecolor='black')
g= g.map(plt.scatter, 'CriticsRating', 'AudienceRating', **kws)
g.set(xlim=(0,100), ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100), (0,100), c='grey', ls='--')

# %%
sns.set_style('darkgrid')
f, ax = plt.subplots(2,2, figsize=(15,15))
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticsRating, ax = ax[0,0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax = ax[0,1])
ax[1,0].hist([movies[movies.Genre=='Action'].BudgetMillions, \
         movies[movies.Genre=='Drama'].BudgetMillions],\
         bins = 15, stacked = True,)
k1 = sns.kdeplot(movies.CriticsRating, movies.AudienceRating,\
                 shade = True, shade_lowest = False, cmap = 'Reds')
k1b = sns.kdeplot(movies.CriticsRating, movies.AudienceRating,\
                  cmap = 'Reds',ax = ax[1,1])
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
